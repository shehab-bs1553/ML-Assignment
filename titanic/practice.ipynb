# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
titanic_data = pd.read_csv('train.csv')

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
numeric_data = titanic_data.select_dtypes(include=['int64', 'float64'])

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load titanic data into a DataFrame
titanic_data = pd.read_csv('train.csv')

# Drop non-numeric columns
numeric_data = titanic_data.select_dtypes(include=['int64', 'float64'])

# Display the heatmap of correlations
sns.heatmap(numeric_data.corr(), cmap="Blues")
plt.show()

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=.25)
for train_indices, test_indices in split.split(titanic_data, titanic_data[["Survived","Pclass","Sex"]]):
    strat_train_set = titanic_data.loc[train_indices]
    strat_test_set = titanic_data.loc[test_indices]

# %% [markdown]
# Histogram plot for survived and Passenger class data:

# %%
plt.subplot(1,2,1)
strat_train_set['Survived'].hist()
strat_train_set['Pclass'].hist()

plt.subplot(1,2,2)
strat_test_set['Survived'].hist()
strat_test_set['Pclass'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Show the train_set information:

# %%
strat_train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 668 entries, 467 to 696
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  668 non-null    int64
#  1   Survived     668 non-null    int64
#  2   Pclass       668 non-null    int64
#  3   Name         668 non-null    object
#  4   Sex          668 non-null    object
#  5   Age          535 non-null    float64
#  6   SibSp        668 non-null    int64
#  7   Parch        668 non-null    int64
#  8   Ticket       668 non-null    object
#  9   Fare         668 non-null    float64
#  10  Cabin        160 non-null    object
#  11  Embarked     666 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 67.8+ KB

# %% [markdown]
# Fill the null values with the mean of the age value:

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.impute import SimpleImputer

class AgeImputer (BaseEstimator, TransformerMixin):
    
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        imputer = SimpleImputer(strategy="mean")
        X['Age'] = imputer.fit_transform(X[['Age']])
        return X

# %% [markdown]
# Extend column into binary columns

# %%
from sklearn.preprocessing import OneHotEncoder

class FeatureEncoder (BaseEstimator, TransformerMixin):
    
    def fit(self, X, y= None):
        return self
    def transform(self, X):
        encoder = OneHotEncoder()
        matrix = encoder.fit_transform(X[['Embarked']]).toarray()
        
        column_names = ["C", "S", "Q", "N"]
        
        for i in range (len(matrix.T)):
            X[column_names[i]]= matrix.T[i]
        matrix = encoder.fit_transform(X[['Sex']]).toarray()
        
        column_names= ["Female", "Male"]
        
        for i in range(len(matrix.T)):
            X[column_names[i]] = matrix.T[i]
        return X

# %% [markdown]
# Delete the unused column:

# %%
class FeatureDropper(BaseEstimator, TransformerMixin):
    
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return X.drop(["Embarked", "Name", "Ticket", "Cabin", "Sex", "N"], axis=1, errors = "Ignore")

# %%
from sklearn.pipeline import Pipeline
pipeline = Pipeline([("AgeImputer", AgeImputer()),
                     ("FeatureEncoder", FeatureEncoder()),
                     ("FeatureDropper", FeatureDropper())])

# %%
strat_train_set = pipeline.fit_transform(strat_train_set)

# %%
AgeImputer(strat_train_set)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 AgeImputer(strat_train_set)
#
# TypeError: AgeImputer() takes no arguments

# %%
FeatureEncoder(strat_train_set)

# %%
FeatureDropper(strat_train_set)

# %%
strat_train_set
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch      Fare    C    S  \
# 467          468         0       1  56.0      0      0   26.5500  0.0  0.0
# 670          671         1       2  40.0      1      1   39.0000  0.0  0.0
# 192          193         1       3  19.0      1      0    7.8542  0.0  0.0
# 10            11         1       3   4.0      1      1   16.7000  0.0  0.0
# 827          828         1       2   1.0      0      2   37.0042  1.0  0.0
# ..           ...       ...     ...   ...    ...    ...       ...  ...  ...
# 443          444         1       2  28.0      0      0   13.0000  0.0  0.0
# 247          248         1       2  24.0      0      2   14.5000  0.0  0.0
# 818          819         0       3  43.0      0      0    6.4500  0.0  0.0
# 698          699         0       1  49.0      1      1  110.8833  1.0  0.0
# 696          697         0       3  44.0      0      0    8.0500  0.0  0.0
#
#        Q  Female  Male
# 467  1.0     0.0   1.0
# ...

# %%
strat_train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 668 entries, 467 to 696
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  668 non-null    int64
#  1   Survived     668 non-null    int64
#  2   Pclass       668 non-null    int64
#  3   Age          668 non-null    float64
#  4   SibSp        668 non-null    int64
#  5   Parch        668 non-null    int64
#  6   Fare         668 non-null    float64
#  7   C            668 non-null    float64
#  8   S            668 non-null    float64
#  9   Q            668 non-null    float64
#  10  Female       668 non-null    float64
#  11  Male         668 non-null    float64
# dtypes: float64(7), int64(5)
# memory usage: 67.8 KB

# %%
from sklearn.preprocessing import StandardScaler

X = strat_train_set.drop(['Survived'], axis=1)
Y = strat_train_set['Survived']

scaler = StandardScaler()
X_data = scaler.fit_transform(X)
Y_data = Y.to_numpy()

# %%
X_data
# Out:
# array([[ 0.07420031, -1.56570494,  1.9606567 , ...,  0.62814968,
#         -0.73669883,  0.73669883],
#        [ 0.85637218, -0.36903343,  0.7631519 , ...,  0.62814968,
#          1.35740679, -1.35740679],
#        [-0.98539212,  0.82763808, -0.80857315, ...,  0.62814968,
#          1.35740679, -1.35740679],
#        ...,
#        [ 1.42662556,  0.82763808,  0.98768405, ...,  0.62814968,
#         -0.73669883,  0.73669883],
#        [ 0.96425795, -1.56570494,  1.43674835, ..., -1.59197724,
#         -0.73669883,  0.73669883],
#        [ 0.95655182,  0.82763808,  1.0625281 , ...,  0.62814968,
#         -0.73669883,  0.73669883]])

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection  import GridSearchCV

clf = RandomForestClassifier()

param_gird = [
    {"n_estimators": [10,20,100,200,500], "max_depth": [None, 5,10,15], "min_samples_split": [2,3,4,5]}
]

grid_search = GridSearchCV(clf, param_gird, cv=3, scoring="accuracy", return_train_score= True)
grid_search.fit(X_data,Y_data)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(),
#              param_grid=[{'max_depth': [None, 5, 10, 15],
#                           'min_samples_split': [2, 3, 4, 5],
#                           'n_estimators': [10, 20, 100, 200, 500]}],
#              return_train_score=True, scoring='accuracy')

# %%
final_clf = grid_search.best_estimator_

# %%
final_clf
# Out:
# RandomForestClassifier(max_depth=10, min_samples_split=3)

# %%
strat_test_set = pipeline.fit_transform(strat_test_set)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 strat_test_set = pipeline.fit_transform(strat_test_set)
#
# File c:\Users\BS-Test\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\BS-Test\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\pipeline.py:543, in Pipeline.fit_transform(self, X, y, **params)
#     541 last_step_params = routed_params[self.steps[-1][0]]
#     542 if hasattr(last_step, "fit_transform"):
# ...

# %%
strat_test_set
# Out:
#      PassengerId  Survived  Pclass        Age  SibSp  Parch     Fare    C  \
# 74            75         1       3  32.000000      0      0  56.4958  0.0
# 600          601         1       2  24.000000      2      1  27.0000  0.0
# 745          746         0       1  70.000000      1      1  71.0000  0.0
# 186          187         1       3  29.222712      1      0  15.5000  0.0
# 194          195         1       1  44.000000      0      0  27.7208  1.0
# ..           ...       ...     ...        ...    ...    ...      ...  ...
# 217          218         0       2  42.000000      1      0  27.0000  0.0
# 300          301         1       3  29.222712      0      0   7.7500  0.0
# 410          411         0       3  29.222712      0      0   7.8958  0.0
# 169          170         0       3  28.000000      0      0  56.4958  0.0
# 282          283         0       3  16.000000      0      0   9.5000  0.0
#
#        S    Q  Female  Male
# 74   0.0  1.0     0.0   1.0
# ...

# %%
x_test = strat_test_set.drop(['Survived'], axis=1)
Y_test = strat_test_set['Survived']

scaler = StandardScaler()
X_data_test = scaler.fit_transform(x_test)
Y_data_test = Y_test.to_numpy()

# %%
final_clf.score(X_data_test, Y_data_test)
# Out:
# 0.8251121076233184

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
final_data = pipeline.fit_transform(titanic_data)

# %%
final_data
# Out:
#      PassengerId  Survived  Pclass        Age  SibSp  Parch     Fare    C  \
# 0              1         0       3  22.000000      1      0   7.2500  0.0
# 1              2         1       1  38.000000      1      0  71.2833  1.0
# 2              3         1       3  26.000000      0      0   7.9250  0.0
# 3              4         1       1  35.000000      1      0  53.1000  0.0
# 4              5         0       3  35.000000      0      0   8.0500  0.0
# ..           ...       ...     ...        ...    ...    ...      ...  ...
# 886          887         0       2  27.000000      0      0  13.0000  0.0
# 887          888         1       1  19.000000      0      0  30.0000  0.0
# 888          889         0       3  29.699118      1      2  23.4500  0.0
# 889          890         1       1  26.000000      0      0  30.0000  1.0
# 890          891         0       3  32.000000      0      0   7.7500  0.0
#
#        S    Q  Female  Male
# 0    0.0  1.0     0.0   1.0
# ...

# %%
X_final = final_data.drop(['Survived'], axis=1)
Y_final = final_data['Survived']

scaler = StandardScaler()
X_final_data = scaler.fit_transform(X_final)
Y_final_data = Y_final.to_numpy()

# %%
prod_clf = RandomForestClassifier()

param_gird = [
    {"n_estimators": [10,20,100,200,500], "max_depth": [None, 5,10,15], "min_samples_split": [2,3,4,5]}
]

grid_search = GridSearchCV(prod_clf, param_gird, cv=3, scoring="accuracy", return_train_score= True)
grid_search.fit(X_data,Y_data)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(),
#              param_grid=[{'max_depth': [None, 5, 10, 15],
#                           'min_samples_split': [2, 3, 4, 5],
#                           'n_estimators': [10, 20, 100, 200, 500]}],
#              return_train_score=True, scoring='accuracy')

# %%
prod_final_cls= grid_search.best_estimator_

# %%
prod_final_cls
# Out:
# RandomForestClassifier(max_depth=5, min_samples_split=5, n_estimators=200)

# %%
titanic_test_data = pd.read_csv("test.csv")

# %%
titanic_test_data
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  SibSp  Parch              Ticket      Fare Cabin  \
# ...

# %%
titanic_test_data
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  SibSp  Parch              Ticket      Fare Cabin  \
# ...

# %%
final_test_data = pipeline.fit_transform(titanic_test_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 final_test_data = pipeline.fit_transform(titanic_test_data)
#
# File c:\Users\BS-Test\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\BS-Test\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\pipeline.py:543, in Pipeline.fit_transform(self, X, y, **params)
#     541 last_step_params = routed_params[self.steps[-1][0]]
#     542 if hasattr(last_step, "fit_transform"):
# ...
